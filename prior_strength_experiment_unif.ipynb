# %%
# Cell 1: Import Libraries and Set Configuration
"""
Experiment: Chain graph with random prior on X1, uniform priors on X2-X10
Vary random seed and plot KL divergence against seed
"""

import numpy as np
import matplotlib.pyplot as plt
from scipy.ndimage import gaussian_filter1d
import sys
sys.path.insert(0, '/home/tom/Projects/gbp_clt/src')
import config as cfg
import distribution_management as dm
from factor_graph import FactorGraph
from belief_propagation import run_belief_propagation
import optimisation as opt

# Fixed parameters
cfg.belief_discretisation = 128
cfg.smoothing_width = 8
cfg.prior_width = 8
cfg.num_iterations = 20  # Enough iterations for convergence
cfg.min_measurement = 0
cfg.max_measurement = 63
cfg.measurement_range = np.linspace(cfg.min_measurement, cfg.max_measurement, cfg.belief_discretisation)

# Select a few representative exponent values to visualize
# n_samples = np.logspace(-3, 3, num=100)
clip_fractions = np.linspace(0.0, 0.495, num=100)
prior_noise_smoothing_width = 5.0

# Experiment parameters
num_variables = 20
num_seeds = 100

# %%
# Cell 2: helper functions

# def create_uniform_perturbed_by_white_noise(n):    
#     white_noise = np.random.rand(cfg.belief_discretisation)
#     white_noise = gaussian_filter1d(white_noise, sigma=prior_noise_smoothing_width) #testing smoothing
    
#     if n > 100:
#         # compute in log space to avoid numerical issues
#         log_white_noise = n * np.log(white_noise + 1e-300)  # Add small value to avoid log(0)
#         white_noise = np.exp(log_white_noise - np.max(log_white_noise))  # Subtract max for numerical stability
#     else:
#         white_noise = white_noise**n
#     white_noise = dm.normalise(white_noise)
#     return white_noise

def create_clipped_uniform(clip_fraction):
    """
    Create a uniform distribution with clipped ends.
    clip_fraction: fraction to clip from EACH end (0.0 = uniform, 0.5 = spike)
    """
    distribution = np.ones(cfg.belief_discretisation)
    
    # Calculate how many bins to zero out from each end
    bins_to_clip = int(clip_fraction * cfg.belief_discretisation)
    
    # Clip from both ends
    if bins_to_clip > 0:
        distribution[:bins_to_clip] = 0.0
        distribution[-bins_to_clip:] = 0.0
    
    # Normalize
    distribution = dm.normalise(distribution)
    return distribution

def optimise_gaussian_kl_robust(y_values, x_values):
    """Find Gaussian that minimizes KL divergence from target_belief"""
    bin_width = (x_values[-1] - x_values[0]) / len(x_values)
    sigma_min = 2*bin_width
    sigma_max = (x_values[-1] - x_values[0]) * 10.0
    num_sigma_steps = 100
    
    optimal_mean = x_values[np.argmax(y_values)]
    sigma_search_values = np.logspace(np.log10(sigma_min), np.log10(sigma_max), num_sigma_steps)
    min_kl = float('inf')
    optimal_sigma = None
        
    for sigma_candidate in sigma_search_values:
        y_gauss = opt.create_gaussian_distribution(x_values, sigma_candidate, mu=optimal_mean)
        current_kl = opt.kl_divergence_numba(y_values, y_gauss)

        if np.isnan(current_kl):
            continue

        if current_kl < min_kl:
            min_kl = current_kl
            optimal_sigma = sigma_candidate

    return min_kl, optimal_sigma, optimal_mean

def sample_evenly(arr, n):
    # n must be <= len(arr)
    idx = np.linspace(0, len(arr)-1, n, dtype=int)
    return arr[idx], idx

def calculate_std_dev(distribution, x_values):
    mean = np.sum(distribution * x_values)
    variance = np.sum(distribution * (x_values - mean)**2)
    std_dev = np.sqrt(variance)
    return std_dev

def calculate_entropy_bit(distribution):
    p = distribution + 1e-12  # Avoid log(0)
    entropy = -np.sum(p * np.log2(p))
    return entropy

# %%
# Cell 3: Run Experiment

seeds = np.arange(42, 42+num_seeds)
seed_for_visualisation = 42

all_kl_divergences = []     # Shape: (num_seeds, len(n_samples))
all_final_beliefs_x10 = []  # Shape: (num_seeds, len(n_samples), belief_discretisation)
all_entropy_values = []     # Shape: (num_seeds, len(n_samples))
all_std_dev_values = []     # Shape: (num_seeds, len(n_samples))

print(f"Running chain graph experiment with {num_variables} variables...")
print(f"Testing {num_seeds} different random seeds\n")

for seed in seeds:
    print(f"Running seed {seed}...")

    # Set random seed
    cfg.random_seed = seed
    cfg.rng = np.random.default_rng(seed=seed)
    np.random.seed(seed)

    seed_kl_divergences = []
    seed_final_beliefs_x10 = []
    seed_entropy_values = []
    seed_std_dev_values = []

    for clip_frac in clip_fractions:
        print(f" Testing seed {seed}, clip_fraction={clip_frac:.4f}...")

        # Build factor graph - chain structure
        graph = FactorGraph()
        graph.add_variables(num_variables, cfg.belief_discretisation)

        # Add smoothing factors to create chain: X1-X2-X3-...-X10
        kernel_range = np.linspace(-cfg.smoothing_width//2, cfg.smoothing_width//2, cfg.belief_discretisation)
        smoothing_kernel = dm.create_random_prior_distribution(kernel_range, prior_width=cfg.prior_width)
        smoothing_function = dm.create_smoothing_factor_distribution(
            cfg.belief_discretisation, 
            kernel=smoothing_kernel
        )

        for i in range(num_variables - 1):
            graph.add_factor(
                [graph.variables[i], graph.variables[i + 1]], 
                function=smoothing_function
            )

        # Add priors
        # All variables get uniform priors
        # X1 gets random (spiky white noise) prior
        random_prior = dm.create_random_prior_distribution(cfg.measurement_range, prior_width=cfg.prior_width)
        graph.add_factor([graph.variables[0]], random_prior, factor_type='prior')
        
        # X2-X10 get uniform priors
        prior_distribution = create_clipped_uniform(clip_frac)
        prior_entropy = calculate_entropy_bit(prior_distribution)
        for i in range(1,num_variables):
            graph.add_factor([graph.variables[i]], prior_distribution, factor_type='prior')

        # Run belief propagation
        graph = run_belief_propagation(graph, cfg.num_iterations)

        # Calculate KL divergence for X10 (last variable)
        x10_belief = graph.variables[-1].belief
        min_kl, _, _ = optimise_gaussian_kl_robust(x10_belief, cfg.measurement_range)
        seed_kl_divergences.append(min_kl)
        seed_final_beliefs_x10.append(x10_belief.copy())
        seed_entropy_values.append(prior_entropy)
        seed_std_dev_values.append(calculate_std_dev(prior_distribution, cfg.measurement_range))

        print(f"  X10 KL divergence: {min_kl:.6f}\n")
    
    all_kl_divergences.append(seed_kl_divergences)
    all_final_beliefs_x10.append(seed_final_beliefs_x10)
    all_entropy_values.append(seed_entropy_values)
    all_std_dev_values.append(seed_std_dev_values)

# Convert to numpy arrays for easier indexing
all_kl_divergences = np.array(all_kl_divergences)        # Shape: (num_seeds, len(n_samples))
all_final_beliefs_x10 = np.array(all_final_beliefs_x10)  # Shape: (num_seeds, len(n_samples), belief_discretisation)
all_entropy_values = np.array(all_entropy_values)        # Shape: (num_seeds, len(n_samples))
all_std_dev_values = np.array(all_std_dev_values)        # Shape: (num_seeds, len(n_samples))

# Extract single seed for visualization (cells 4 and 5)
visualization_seed_idx = np.where(seeds == seed_for_visualisation)[0][0]
kl_divergences = all_kl_divergences[visualization_seed_idx]
final_beliefs_x10 = all_final_beliefs_x10[visualization_seed_idx]
entropy_values = all_entropy_values[visualization_seed_idx]  # Use stored entropy values
std_dev_values = all_std_dev_values[visualization_seed_idx] # Use stored std dev values

print(f"Experiment complete!")
print(f"Mean KL divergence across all seeds: {np.mean(all_kl_divergences):.6f}")
print(f"Std KL divergence across all seeds: {np.std(all_kl_divergences):.6f}")
# Out:
# Running chain graph experiment with 20 variables...
# Testing 50 different random seeds
#
# Running seed 42...
#  Testing seed 42, clip_fraction=0.0000...
# Adding variables to graph...
# BP Stage 1: Converting graph to numerical representation...
# BP Stage 2: Running BP iterations...
# BP Stage 3: Updating graph objects with final beliefs...
#   X10 KL divergence: 0.000904
#
#  Testing seed 42, clip_fraction=0.0050...
# Adding variables to graph...
# BP Stage 1: Converting graph to numerical representation...
# BP Stage 2: Running BP iterations...
# BP Stage 3: Updating graph objects with final beliefs...
#   X10 KL divergence: 0.000589
#
#  Testing seed 42, clip_fraction=0.0100...
# Adding variables to graph...
# BP Stage 1: Converting graph to numerical representation...
# BP Stage 2: Running BP iterations...
# BP Stage 3: Updating graph objects with final beliefs...
#   X10 KL divergence: 0.000986
#
#  Testing seed 42, clip_fraction=0.0150...
# Adding variables to graph...
# BP Stage 1: Converting graph to numerical representation...
# BP Stage 2: Running BP iterations...
# BP Stage 3: Updating graph objects with final beliefs...
#   X10 KL divergence: 0.005288
#
#  Testing seed 42, clip_fraction=0.0200...
# Adding variables to graph...
# BP Stage 1: Converting graph to numerical representation...
# BP Stage 2: Running BP iterations...
# BP Stage 3: Updating graph objects with final beliefs...
#   X10 KL divergence: 0.002208
#
#  Testing seed 42, clip_fraction=0.0250...
# Adding variables to graph...
# BP Stage 1: Converting graph to numerical representation...
# BP Stage 2: Running BP iterations...
# BP Stage 3: Updating graph objects with final beliefs...
#   X10 KL divergence: 0.000808
#
#  Testing seed 42, clip_fraction=0.0300...
# Adding variables to graph...
# BP Stage 1: Converting graph to numerical representation...
# BP Stage 2: Running BP iterations...
# BP Stage 3: Updating graph objects with final beliefs...
#   X10 KL divergence: 0.004263
#
#  Testing seed 42, clip_fraction=0.0350...
# Adding variables to graph...
# BP Stage 1: Converting graph to numerical representation...
# BP Stage 2: Running BP iterations...
# BP Stage 3: Updating graph objects with final beliefs...
#   X10 KL divergence: 0.000407
#
#  Testing seed 42, clip_fraction=0.0400...
# Adding variables to graph...
# BP Stage 1: Converting graph to numerical representation...
# BP Stage 2: Running BP iterations...
# BP Stage 3: Updating graph objects with final beliefs...
#   X10 KL divergence: 0.000889
#
#  Testing seed 42, clip_fraction=0.0450...
# Adding variables to graph...
# BP Stage 1: Converting graph to numerical representation...
# BP Stage 2: Running BP iterations...
# BP Stage 3: Updating graph objects with final beliefs...
#   X10 KL divergence: 0.001109
#
#  Testing seed 42, clip_fraction=0.0500...
# Adding variables to graph...
# BP Stage 1: Converting graph to numerical representation...
# BP Stage 2: Running BP iterations...
# BP Stage 3: Updating graph objects with final beliefs...
#   X10 KL divergence: 0.001708
#
#  Testing seed 42, clip_fraction=0.0550...
# Adding variables to graph...
# BP Stage 1: Converting graph to numerical representation...
# BP Stage 2: Running BP iterations...
# BP Stage 3: Updating graph objects with final beliefs...
#   X10 KL divergence: 0.001100
#
#  Testing seed 42, clip_fraction=0.0600...
# Adding variables to graph...
# BP Stage 1: Converting graph to numerical representation...
# BP Stage 2: Running BP iterations...
# BP Stage 3: Updating graph objects with final beliefs...
#   X10 KL divergence: 0.000482
#
#  Testing seed 42, clip_fraction=0.0650...
# Adding variables to graph...
# BP Stage 1: Converting graph to numerical representation...
# BP Stage 2: Running BP iterations...
# BP Stage 3: Updating graph objects with final beliefs...
#   X10 KL divergence: 0.001995
#
#  Testing seed 42, clip_fraction=0.0700...
# Adding variables to graph...
# BP Stage 1: Converting graph to numerical representation...
# BP Stage 2: Running BP iterations...
# BP Stage 3: Updating graph objects with final beliefs...
#   X10 KL divergence: 0.004285
#
#  Testing seed 42, clip_fraction=0.0750...
# Adding variables to graph...
# BP Stage 1: Converting graph to numerical representation...
# BP Stage 2: Running BP iterations...
# BP Stage 3: Updating graph objects with final beliefs...
#   X10 KL divergence: 0.001225
#
#  Testing seed 42, clip_fraction=0.0800...
# Adding variables to graph...
# BP Stage 1: Converting graph to numerical representation...
# BP Stage 2: Running BP iterations...
# BP Stage 3: Updating graph objects with final beliefs...
#   X10 KL divergence: 0.002669
#
#  Testing seed 42, clip_fraction=0.0850...
# Adding variables to graph...
# BP Stage 1: Converting graph to numerical representation...
# BP Stage 2: Running BP iterations...
# BP Stage 3: Updating graph objects with final beliefs...
#   X10 KL divergence: 0.001319
#
#  Testing seed 42, clip_fraction=0.0900...
# Adding variables to graph...
# BP Stage 1: Converting graph to numerical representation...
# BP Stage 2: Running BP iterations...
# BP Stage 3: Updating graph objects with final beliefs...
#   X10 KL divergence: 0.001683
#
#  Testing seed 42, clip_fraction=0.0950...
# Adding variables to graph...
# BP Stage 1: Converting graph to numerical representation...
# BP Stage 2: Running BP iterations...
# BP Stage 3: Updating graph objects with final beliefs...
#   X10 KL divergence: 0.001751
#
#  Testing seed 42, clip_fraction=0.1000...
# Adding variables to graph...
# BP Stage 1: Converting graph to numerical representation...
# BP Stage 2: Running BP iterations...
# BP Stage 3: Updating graph objects with final beliefs...
#   X10 KL divergence: 0.002577
#
#  Testing seed 42, clip_fraction=0.1050...
# Adding variables to graph...
# BP Stage 1: Converting graph to numerical representation...
# BP Stage 2: Running BP iterations...
# BP Stage 3: Updating graph objects with final beliefs...
#   X10 KL divergence: 0.001659
#
#  Testing seed 42, clip_fraction=0.1100...
# Adding variables to graph...
# BP Stage 1: Converting graph to numerical representation...
# BP Stage 2: Running BP iterations...
# BP Stage 3: Updating graph objects with final beliefs...
#   X10 KL divergence: 0.001233
#
#  Testing seed 42, clip_fraction=0.1150...
# Adding variables to graph...
# BP Stage 1: Converting graph to numerical representation...
# BP Stage 2: Running BP iterations...
# BP Stage 3: Updating graph objects with final beliefs...
#   X10 KL divergence: 0.011357
#
#  Testing seed 42, clip_fraction=0.1200...
# Adding variables to graph...
# BP Stage 1: Converting graph to numerical representation...
# BP Stage 2: Running BP iterations...
# BP Stage 3: Updating graph objects with final beliefs...
#   X10 KL divergence: 0.000793
#
#  Testing seed 42, clip_fraction=0.1250...
# Adding variables to graph...
# BP Stage 1: Converting graph to numerical representation...
# BP Stage 2: Running BP iterations...
# BP Stage 3: Updating graph objects with final beliefs...
#   X10 KL divergence: 0.001048
#
#  Testing seed 42, clip_fraction=0.1300...
# Adding variables to graph...
# BP Stage 1: Converting graph to numerical representation...
# BP Stage 2: Running BP iterations...
# BP Stage 3: Updating graph objects with final beliefs...
#   X10 KL divergence: 0.003105
#
#  Testing seed 42, clip_fraction=0.1350...
# Adding variables to graph...
# BP Stage 1: Converting graph to numerical representation...
# BP Stage 2: Running BP iterations...
# BP Stage 3: Updating graph objects with final beliefs...
#   X10 KL divergence: 0.001933
#
#  Testing seed 42, clip_fraction=0.1400...
# Adding variables to graph...
# BP Stage 1: Converting graph to numerical representation...
# BP Stage 2: Running BP iterations...
# BP Stage 3: Updating graph objects with final beliefs...
#   X10 KL divergence: 0.001599
#
#  Testing seed 42, clip_fraction=0.1450...
# Adding variables to graph...
# BP Stage 1: Converting graph to numerical representation...
# BP Stage 2: Running BP iterations...
# BP Stage 3: Updating graph objects with final beliefs...
#   X10 KL divergence: 0.004007
#
#  Testing seed 42, clip_fraction=0.1500...
# Adding variables to graph...
# BP Stage 1: Converting graph to numerical representation...
# BP Stage 2: Running BP iterations...
# BP Stage 3: Updating graph objects with final beliefs...
#   X10 KL divergence: 0.001326
#
#  Testing seed 42, clip_fraction=0.1550...
# Adding variables to graph...
# BP Stage 1: Converting graph to numerical representation...
# BP Stage 2: Running BP iterations...
# BP Stage 3: Updating graph objects with final beliefs...
#   X10 KL divergence: 0.001300
#
#  Testing seed 42, clip_fraction=0.1600...
# Adding variables to graph...
# BP Stage 1: Converting graph to numerical representation...
# BP Stage 2: Running BP iterations...
# BP Stage 3: Updating graph objects with final beliefs...
#   X10 KL divergence: 0.003849
#
#  Testing seed 42, clip_fraction=0.1650...
# Adding variables to graph...
# BP Stage 1: Converting graph to numerical representation...
# BP Stage 2: Running BP iterations...
# BP Stage 3: Updating graph objects with final beliefs...
#   X10 KL divergence: 0.015055
#
#  Testing seed 42, clip_fraction=0.1700...
# Adding variables to graph...
# BP Stage 1: Converting graph to numerical representation...
# BP Stage 2: Running BP iterations...
# BP Stage 3: Updating graph objects with final beliefs...
#   X10 KL divergence: 0.001872
#
#  Testing seed 42, clip_fraction=0.1750...
# Adding variables to graph...
# BP Stage 1: Converting graph to numerical representation...
# BP Stage 2: Running BP iterations...
# BP Stage 3: Updating graph objects with final beliefs...
#   X10 KL divergence: 0.000208
#
#  Testing seed 42, clip_fraction=0.1800...
# Adding variables to graph...
# BP Stage 1: Converting graph to numerical representation...
# BP Stage 2: Running BP iterations...
# BP Stage 3: Updating graph objects with final beliefs...
#   X10 KL divergence: 0.058342
#
#  Testing seed 42, clip_fraction=0.1850...
# Adding variables to graph...
# BP Stage 1: Converting graph to numerical representation...
# BP Stage 2: Running BP iterations...
# BP Stage 3: Updating graph objects with final beliefs...
#   X10 KL divergence: 0.003319
#
#  Testing seed 42, clip_fraction=0.1900...
# Adding variables to graph...
# BP Stage 1: Converting graph to numerical representation...
# BP Stage 2: Running BP iterations...
# BP Stage 3: Updating graph objects with final beliefs...
#   X10 KL divergence: 0.001155
#
#  Testing seed 42, clip_fraction=0.1950...
# Adding variables to graph...
# BP Stage 1: Converting graph to numerical representation...
# BP Stage 2: Running BP iterations...
# BP Stage 3: Updating graph objects with final beliefs...
#   X10 KL divergence: 0.001531
#
#  Testing seed 42, clip_fraction=0.2000...
# Adding variables to graph...
# BP Stage 1: Converting graph to numerical representation...
# BP Stage 2: Running BP iterations...
# BP Stage 3: Updating graph objects with final beliefs...
#   X10 KL divergence: 0.016854
#
#  Testing seed 42, clip_fraction=0.2050...
# Adding variables to graph...
# BP Stage 1: Converting graph to numerical representation...
# BP Stage 2: Running BP iterations...
# BP Stage 3: Updating graph objects with final beliefs...
#   X10 KL divergence: 0.053336
#
#  Testing seed 42, clip_fraction=0.2100...
# Adding variables to graph...
# BP Stage 1: Converting graph to numerical representation...
# BP Stage 2: Running BP iterations...
# BP Stage 3: Updating graph objects with final beliefs...
#   X10 KL divergence: 0.047783
#
#  Testing seed 42, clip_fraction=0.2150...
# Adding variables to graph...
# BP Stage 1: Converting graph to numerical representation...
# BP Stage 2: Running BP iterations...
# BP Stage 3: Updating graph objects with final beliefs...
#   X10 KL divergence: 0.007584
#
#  Testing seed 42, clip_fraction=0.2200...
# Adding variables to graph...
# BP Stage 1: Converting graph to numerical representation...
# BP Stage 2: Running BP iterations...
# BP Stage 3: Updating graph objects with final beliefs...
#   X10 KL divergence: 0.001834
#
#  Testing seed 42, clip_fraction=0.2250...
# Adding variables to graph...
# BP Stage 1: Converting graph to numerical representation...
# BP Stage 2: Running BP iterations...
# BP Stage 3: Updating graph objects with final beliefs...
#   X10 KL divergence: 0.255963
#
#  Testing seed 42, clip_fraction=0.2300...
# Adding variables to graph...
# BP Stage 1: Converting graph to numerical representation...
# BP Stage 2: Running BP iterations...
# BP Stage 3: Updating graph objects with final beliefs...
#   X10 KL divergence: 0.005428
#
#  Testing seed 42, clip_fraction=0.2350...
# Adding variables to graph...
# BP Stage 1: Converting graph to numerical representation...
# BP Stage 2: Running BP iterations...
# BP Stage 3: Updating graph objects with final beliefs...
#   X10 KL divergence: 0.005557
#
#  Testing seed 42, clip_fraction=0.2400...
# Adding variables to graph...
# BP Stage 1: Converting graph to numerical representation...
# BP Stage 2: Running BP iterations...
# BP Stage 3: Updating graph objects with final beliefs...
#   X10 KL divergence: 0.000484
#
#  Testing seed 42, clip_fraction=0.2450...
# Adding variables to graph...
# BP Stage 1: Converting graph to numerical representation...
# BP Stage 2: Running BP iterations...
# BP Stage 3: Updating graph objects with final beliefs...
#   X10 KL divergence: 0.064841
#
#  Testing seed 42, clip_fraction=0.2500...
# Adding variables to graph...
# BP Stage 1: Converting graph to numerical representation...
# BP Stage 2: Running BP iterations...
# BP Stage 3: Updating graph objects with final beliefs...
#   X10 KL divergence: 0.180651
#
#  Testing seed 42, clip_fraction=0.2550...
# Adding variables to graph...
# BP Stage 1: Converting graph to numerical representation...
# BP Stage 2: Running BP iterations...
# BP Stage 3: Updating graph objects with final beliefs...
#   X10 KL divergence: 0.102250
#
#  Testing seed 42, clip_fraction=0.2600...
# Adding variables to graph...
# BP Stage 1: Converting graph to numerical representation...
# BP Stage 2: Running BP iterations...
# BP Stage 3: Updating graph objects with final beliefs...
#   X10 KL divergence: 0.009692
#
#  Testing seed 42, clip_fraction=0.2650...
# Adding variables to graph...
# BP Stage 1: Converting graph to numerical representation...
# BP Stage 2: Running BP iterations...
# BP Stage 3: Updating graph objects with final beliefs...
#   X10 KL divergence: 0.005581
#
#  Testing seed 42, clip_fraction=0.2700...
# Adding variables to graph...
# BP Stage 1: Converting graph to numerical representation...
# BP Stage 2: Running BP iterations...
# BP Stage 3: Updating graph objects with final beliefs...
#   X10 KL divergence: 0.131789
#
#  Testing seed 42, clip_fraction=0.2750...
# Adding variables to graph...
# BP Stage 1: Converting graph to numerical representation...
# BP Stage 2: Running BP iterations...
# BP Stage 3: Updating graph objects with final beliefs...
#   X10 KL divergence: 0.255017
#
#  Testing seed 42, clip_fraction=0.2800...
# Adding variables to graph...
# BP Stage 1: Converting graph to numerical representation...
# BP Stage 2: Running BP iterations...
# BP Stage 3: Updating graph objects with final beliefs...
#   X10 KL divergence: 0.011657
#
#  Testing seed 42, clip_fraction=0.2850...
# Adding variables to graph...
# BP Stage 1: Converting graph to numerical representation...
# BP Stage 2: Running BP iterations...
# BP Stage 3: Updating graph objects with final beliefs...
#   X10 KL divergence: 0.427526
#
#  Testing seed 42, clip_fraction=0.2900...
# Adding variables to graph...
# BP Stage 1: Converting graph to numerical representation...
# BP Stage 2: Running BP iterations...
# BP Stage 3: Updating graph objects with final beliefs...
#   X10 KL divergence: 0.068893
#
#  Testing seed 42, clip_fraction=0.2950...
# Adding variables to graph...
# BP Stage 1: Converting graph to numerical representation...
# BP Stage 2: Running BP iterations...
# BP Stage 3: Updating graph objects with final beliefs...
#   X10 KL divergence: 0.031155
#
#  Testing seed 42, clip_fraction=0.3000...
# Adding variables to graph...
# BP Stage 1: Converting graph to numerical representation...
# BP Stage 2: Running BP iterations...
# BP Stage 3: Updating graph objects with final beliefs...
#   X10 KL divergence: 0.012669
#
#  Testing seed 42, clip_fraction=0.3050...
# Adding variables to graph...
# BP Stage 1: Converting graph to numerical representation...
# BP Stage 2: Running BP iterations...
# BP Stage 3: Updating graph objects with final beliefs...
#   X10 KL divergence: 0.010253
#
#  Testing seed 42, clip_fraction=0.3100...
# Adding variables to graph...
# BP Stage 1: Converting graph to numerical representation...
# BP Stage 2: Running BP iterations...
# BP Stage 3: Updating graph objects with final beliefs...
#   X10 KL divergence: 0.118659
#
#  Testing seed 42, clip_fraction=0.3150...
# Adding variables to graph...
# BP Stage 1: Converting graph to numerical representation...
# BP Stage 2: Running BP iterations...
# BP Stage 3: Updating graph objects with final beliefs...
#   X10 KL divergence: 0.204942
#
#  Testing seed 42, clip_fraction=0.3200...
# Adding variables to graph...
# BP Stage 1: Converting graph to numerical representation...
# BP Stage 2: Running BP iterations...
# BP Stage 3: Updating graph objects with final beliefs...
#   X10 KL divergence: 0.071970
#
#  Testing seed 42, clip_fraction=0.3250...
# Adding variables to graph...
# BP Stage 1: Converting graph to numerical representation...
# BP Stage 2: Running BP iterations...
# BP Stage 3: Updating graph objects with final beliefs...
#   X10 KL divergence: 0.057893
#
#  Testing seed 42, clip_fraction=0.3300...
# Adding variables to graph...
# BP Stage 1: Converting graph to numerical representation...
# BP Stage 2: Running BP iterations...
# BP Stage 3: Updating graph objects with final beliefs...
#   X10 KL divergence: 0.134461
#
#  Testing seed 42, clip_fraction=0.3350...
# Adding variables to graph...
# BP Stage 1: Converting graph to numerical representation...
# BP Stage 2: Running BP iterations...
# BP Stage 3: Updating graph objects with final beliefs...
#   X10 KL divergence: 0.273895
#
#  Testing seed 42, clip_fraction=0.3400...
# Adding variables to graph...
# BP Stage 1: Converting graph to numerical representation...
# BP Stage 2: Running BP iterations...
# BP Stage 3: Updating graph objects with final beliefs...
#   X10 KL divergence: 0.125551
#
#  Testing seed 42, clip_fraction=0.3450...
# Adding variables to graph...
# BP Stage 1: Converting graph to numerical representation...
# BP Stage 2: Running BP iterations...
# BP Stage 3: Updating graph objects with final beliefs...
#   X10 KL divergence: 0.147012
#
#  Testing seed 42, clip_fraction=0.3500...
# Adding variables to graph...
# BP Stage 1: Converting graph to numerical representation...
# BP Stage 2: Running BP iterations...
# BP Stage 3: Updating graph objects with final beliefs...
#   X10 KL divergence: 0.066034
#
#  Testing seed 42, clip_fraction=0.3550...
# Adding variables to graph...
# BP Stage 1: Converting graph to numerical representation...
# BP Stage 2: Running BP iterations...
# BP Stage 3: Updating graph objects with final beliefs...
#   X10 KL divergence: 0.082693
#
#  Testing seed 42, clip_fraction=0.3600...
# Adding variables to graph...
# BP Stage 1: Converting graph to numerical representation...
# BP Stage 2: Running BP iterations...
# BP Stage 3: Updating graph objects with final beliefs...
#   X10 KL divergence: 0.199770
#
#  Testing seed 42, clip_fraction=0.3650...
# Adding variables to graph...
# BP Stage 1: Converting graph to numerical representation...
# BP Stage 2: Running BP iterations...
# BP Stage 3: Updating graph objects with final beliefs...
#   X10 KL divergence: 0.072146
#
#  Testing seed 42, clip_fraction=0.3700...
# Adding variables to graph...
# BP Stage 1: Converting graph to numerical representation...
# BP Stage 2: Running BP iterations...
# BP Stage 3: Updating graph objects with final beliefs...
#   X10 KL divergence: 0.194204
#
#  Testing seed 42, clip_fraction=0.3750...
# Adding variables to graph...
# BP Stage 1: Converting graph to numerical representation...
# BP Stage 2: Running BP iterations...
# BP Stage 3: Updating graph objects with final beliefs...
#   X10 KL divergence: 0.262494
#
#  Testing seed 42, clip_fraction=0.3800...
# Adding variables to graph...
# BP Stage 1: Converting graph to numerical representation...
# BP Stage 2: Running BP iterations...
# BP Stage 3: Updating graph objects with final beliefs...
#   X10 KL divergence: 0.050597
#
#  Testing seed 42, clip_fraction=0.3850...
# Adding variables to graph...
# BP Stage 1: Converting graph to numerical representation...
# BP Stage 2: Running BP iterations...
# BP Stage 3: Updating graph objects with final beliefs...
#   X10 KL divergence: 0.369417
#
#  Testing seed 42, clip_fraction=0.3900...
# Adding variables to graph...
# BP Stage 1: Converting graph to numerical representation...
# BP Stage 2: Running BP iterations...
# BP Stage 3: Updating graph objects with final beliefs...
#   X10 KL divergence: 0.239830
#
#  Testing seed 42, clip_fraction=0.3950...
# Adding variables to graph...
# BP Stage 1: Converting graph to numerical representation...
# BP Stage 2: Running BP iterations...
# BP Stage 3: Updating graph objects with final beliefs...
#   X10 KL divergence: 0.178267
#
#  Testing seed 42, clip_fraction=0.4000...
# Adding variables to graph...
# BP Stage 1: Converting graph to numerical representation...
# BP Stage 2: Running BP iterations...
# BP Stage 3: Updating graph objects with final beliefs...
#   X10 KL divergence: 0.162594
#
#  Testing seed 42, clip_fraction=0.4050...
# Adding variables to graph...
# BP Stage 1: Converting graph to numerical representation...
# BP Stage 2: Running BP iterations...
# BP Stage 3: Updating graph objects with final beliefs...
#   X10 KL divergence: 0.045765
#
#  Testing seed 42, clip_fraction=0.4100...
# Adding variables to graph...
# BP Stage 1: Converting graph to numerical representation...
# BP Stage 2: Running BP iterations...
# BP Stage 3: Updating graph objects with final beliefs...
#   X10 KL divergence: 0.113298
#
#  Testing seed 42, clip_fraction=0.4150...
# Adding variables to graph...
# BP Stage 1: Converting graph to numerical representation...
# BP Stage 2: Running BP iterations...
# BP Stage 3: Updating graph objects with final beliefs...
#   X10 KL divergence: 0.161954
#
#  Testing seed 42, clip_fraction=0.4200...
# Adding variables to graph...
# BP Stage 1: Converting graph to numerical representation...
# BP Stage 2: Running BP iterations...
# BP Stage 3: Updating graph objects with final beliefs...
#   X10 KL divergence: 0.172750
#
#  Testing seed 42, clip_fraction=0.4250...
# Adding variables to graph...
# BP Stage 1: Converting graph to numerical representation...
# BP Stage 2: Running BP iterations...
# BP Stage 3: Updating graph objects with final beliefs...
#   X10 KL divergence: 0.376728
#
#  Testing seed 42, clip_fraction=0.4300...
# Adding variables to graph...
# BP Stage 1: Converting graph to numerical representation...
# BP Stage 2: Running BP iterations...
# BP Stage 3: Updating graph objects with final beliefs...
#   X10 KL divergence: 0.099473
#
#  Testing seed 42, clip_fraction=0.4350...
# Adding variables to graph...
# BP Stage 1: Converting graph to numerical representation...
# BP Stage 2: Running BP iterations...
# BP Stage 3: Updating graph objects with final beliefs...
#   X10 KL divergence: 0.111208
#
#  Testing seed 42, clip_fraction=0.4400...
# Adding variables to graph...
# BP Stage 1: Converting graph to numerical representation...
# BP Stage 2: Running BP iterations...
# BP Stage 3: Updating graph objects with final beliefs...
#   X10 KL divergence: 0.270562
#
#  Testing seed 42, clip_fraction=0.4450...
# Adding variables to graph...
# BP Stage 1: Converting graph to numerical representation...
# BP Stage 2: Running BP iterations...
# BP Stage 3: Updating graph objects with final beliefs...
#   X10 KL divergence: 0.229565
#
#  Testing seed 42, clip_fraction=0.4500...
# Adding variables to graph...
# BP Stage 1: Converting graph to numerical representation...
# BP Stage 2: Running BP iterations...
# BP Stage 3: Updating graph objects with final beliefs...
#   X10 KL divergence: 0.327438
#
#  Testing seed 42, clip_fraction=0.4550...
# Adding variables to graph...
# BP Stage 1: Converting graph to numerical representation...
# BP Stage 2: Running BP iterations...
# BP Stage 3: Updating graph objects with final beliefs...
#   X10 KL divergence: 0.160161
#
#  Testing seed 42, clip_fraction=0.4600...
# Adding variables to graph...
# BP Stage 1: Converting graph to numerical representation...
# BP Stage 2: Running BP iterations...
# BP Stage 3: Updating graph objects with final beliefs...
#   X10 KL divergence: 0.080649
#
#  Testing seed 42, clip_fraction=0.4650...
# Adding variables to graph...
# BP Stage 1: Converting graph to numerical representation...
# BP Stage 2: Running BP iterations...
# BP Stage 3: Updating graph objects with final beliefs...
#   X10 KL divergence: 0.173038
#
#  Testing seed 42, clip_fraction=0.4700...
# Adding variables to graph...
# BP Stage 1: Converting graph to numerical representation...
# BP Stage 2: Running BP iterations...
# BP Stage 3: Updating graph objects with final beliefs...
#   X10 KL divergence: 0.352460
#
#  Testing seed 42, clip_fraction=0.4750...
# Adding variables to graph...
# BP Stage 1: Converting graph to numerical representation...
# BP Stage 2: Running BP iterations...
# BP Stage 3: Updating graph objects with final beliefs...
#   X10 KL divergence: 0.120687
#
#  Testing seed 42, clip_fraction=0.4800...
# Adding variables to graph...
# BP Stage 1: Converting graph to numerical representation...
# BP Stage 2: Running BP iterations...
# BP Stage 3: Updating graph objects with final beliefs...
#   X10 KL divergence: 0.580904
#
#  Testing seed 42, clip_fraction=0.4850...
# Adding variables to graph...
# BP Stage 1: Converting graph to numerical representation...
# BP Stage 2: Running BP iterations...
# BP Stage 3: Updating graph objects with final beliefs...
#   X10 KL divergence: 0.616667
#
#  Testing seed 42, clip_fraction=0.4900...
# Adding variables to graph...
# BP Stage 1: Converting graph to numerical representation...
# BP Stage 2: Running BP iterations...
# BP Stage 3: Updating graph objects with final beliefs...
#   X10 KL divergence: 0.393306
#
#  Testing seed 42, clip_fraction=0.4950...
# Adding variables to graph...
# BP Stage 1: Converting graph to numerical representation...
# BP Stage 2: Running BP iterations...
# BP Stage 3: Updating graph objects with final beliefs...
#   X10 KL divergence: 0.998493
#
# Running seed 43...
#  Testing seed 43, clip_fraction=0.0000...
# Adding variables to graph...
# BP Stage 1: Converting graph to numerical representation...
# BP Stage 2: Running BP iterations...
# BP Stage 3: Updating graph objects with final beliefs...
#   X10 KL divergence: 0.002035
#
#  Testing seed 43, clip_fraction=0.0050...
# Adding variables to graph...
# BP Stage 1: Converting graph to numerical representation...
# BP Stage 2: Running BP iterations...
# BP Stage 3: Updating graph objects with final beliefs...
#   X10 KL divergence: 0.000704
#
#  Testing seed 43, clip_fraction=0.0100...
# Adding variables to graph...
# BP Stage 1: Converting graph to numerical representation...
# BP Stage 2: Running BP iterations...
# BP Stage 3: Updating graph objects with final beliefs...
#   X10 KL divergence: 0.000785
#
#  Testing seed 43, clip_fraction=0.0150...
# Adding variables to graph...
# BP Stage 1: Converting graph to numerical representation...
# BP Stage 2: Running BP iterations...
# BP Stage 3: Updating graph objects with final beliefs...
#   X10 KL divergence: 0.000611
#
#  Testing seed 43, clip_fraction=0.0200...
# Adding variables to graph...
# BP Stage 1: Converting graph to numerical representation...
# BP Stage 2: Running BP iterations...
# BP Stage 3: Updating graph objects with final beliefs...
#   X10 KL divergence: 0.001803
#
#  Testing seed 43, clip_fraction=0.0250...
# Adding variables to graph...
# BP Stage 1: Converting graph to numerical representation...
# BP Stage 2: Running BP iterations...
# BP Stage 3: Updating graph objects with final beliefs...
#   X10 KL divergence: 0.000947
#
#  Testing seed 43, clip_fraction=0.0300...
# Adding variables to graph...
# BP Stage 1: Converting graph to numerical representation...
# BP Stage 2: Running BP iterations...
# BP Stage 3: Updating graph objects with final beliefs...
#   X10 KL divergence: 0.003756
#
#  Testing seed 43, clip_fraction=0.0350...
# Adding variables to graph...
# BP Stage 1: Converting graph to numerical representation...
# BP Stage 2: Running BP iterations...
# BP Stage 3: Updating graph objects with final beliefs...
#   X10 KL divergence: 0.002384
#
#  Testing seed 43, clip_fraction=0.0400...
# Adding variables to graph...
# BP Stage 1: Converting graph to numerical representation...
# BP Stage 2: Running BP iterations...
# BP Stage 3: Updating graph objects with final beliefs...
#   X10 KL divergence: 0.008668
#
#  Testing seed 43, clip_fraction=0.0450...
# Adding variables to graph...
# BP Stage 1: Converting graph to numerical representation...
# BP Stage 2: Running BP iterations...
# BP Stage 3: Updating graph objects with final beliefs...
#   X10 KL divergence: 0.002461
#
#  Testing seed 43, clip_fraction=0.0500...
# Adding variables to graph...
# BP Stage 1: Converting graph to numerical representation...
# BP Stage 2: Running BP iterations...
# BP Stage 3: Updating graph objects with final beliefs...
#   X10 KL divergence: 0.001260
#
#  Testing seed 43, clip_fraction=0.0550...
# Adding variables to graph...
# BP Stage 1: Converting graph to numerical representation...
# BP Stage 2: Running BP iterations...
# BP Stage 3: Updating graph objects with final beliefs...
#   X10 KL divergence: 0.000457
#
#  Testing seed 43, clip_fraction=0.0600...
# Adding variables to graph...
# BP Stage 1: Converting graph to numerical representation...
# BP Stage 2: Running BP iterations...
# BP Stage 3: Updating graph objects with final beliefs...
#   X10 KL divergence: 0.003070
#
#  Testing seed 43, clip_fraction=0.0650...
# Adding variables to graph...
# BP Stage 1: Converting graph to numerical representation...
# BP Stage 2: Running BP iterations...
# BP Stage 3: Updating graph objects with final beliefs...
#   X10 KL divergence: 0.004250
#
#  Testing seed 43, clip_fraction=0.0700...
# Adding variables to graph...
# BP Stage 1: Converting graph to numerical representation...
# BP Stage 2: Running BP iterations...
# BP Stage 3: Updating graph objects with final beliefs...
#   X10 KL divergence: 0.000201
#
#  Testing seed 43, clip_fraction=0.0750...
# Adding variables to graph...
# BP Stage 1: Converting graph to numerical representation...
# BP Stage 2: Running BP iterations...
# BP Stage 3: Updating graph objects with final beliefs...
#   X10 KL divergence: 0.003309
#
#  Testing seed 43, clip_fraction=0.0800...
# Adding variables to graph...
# BP Stage 1: Converting graph to numerical representation...
# BP Stage 2: Running BP iterations...
# BP Stage 3: Updating graph objects with final beliefs...
#   X10 KL divergence: 0.000722
#
#  Testing seed 43, clip_fraction=0.0850...
# Adding variables to graph...
# BP Stage 1: Converting graph to numerical representation...
# BP Stage 2: Running BP iterations...
# BP Stage 3: Updating graph objects with final beliefs...
#   X10 KL divergence: 0.003065
#
#  Testing seed 43, clip_fraction=0.0900...
# Adding variables to graph...
# BP Stage 1: Converting graph to numerical representation...
# BP Stage 2: Running BP iterations...
# BP Stage 3: Updating graph objects with final beliefs...
#   X10 KL divergence: 0.003398
#
#  Testing seed 43, clip_fraction=0.0950...
# Adding variables to graph...
# BP Stage 1: Converting graph to numerical representation...
# BP Stage 2: Running BP iterations...
# BP Stage 3: Updating graph objects with final beliefs...
#   X10 KL divergence: 0.002289
#
#  Testing seed 43, clip_fraction=0.1000...
# Adding variables to graph...
# BP Stage 1: Converting graph to numerical representation...
# BP Stage 2: Running BP iterations...
# BP Stage 3: Updating graph objects with final beliefs...
#   X10 KL divergence: 0.000926
#
#  Testing seed 43, clip_fraction=0.1050...
# Adding variables to graph...
# BP Stage 1: Converting graph to numerical representation...
# BP Stage 2: Running BP iterations...
# BP Stage 3: Updating graph objects with final beliefs...
#   X10 KL divergence: 0.005837
#
#  Testing seed 43, clip_fraction=0.1100...
# Adding variables to graph...
# BP Stage 1: Converting graph to numerical representation...
# BP Stage 2: Running BP iterations...
# BP Stage 3: Updating graph objects with final beliefs...
#   X10 KL divergence: 0.001361
#
#  Testing seed 43, clip_fraction=0.1150...
# Adding variables to graph...
# BP Stage 1: Converting graph to numerical representation...
# BP Stage 2: Running BP iterations...
# BP Stage 3: Updating graph objects with final beliefs...
#   X10 KL divergence: 0.007125
#
#  Testing seed 43, clip_fraction=0.1200...
# Adding variables to graph...
# BP Stage 1: Converting graph to numerical representation...
# BP Stage 2: Running BP iterations...
# BP Stage 3: Updating graph objects with final beliefs...
#   X10 KL divergence: 0.003944
#
#  Testing seed 43, clip_fraction=0.1250...
# Adding variables to graph...
# BP Stage 1: Converting graph to numerical representation...
# BP Stage 2: Running BP iterations...
# BP Stage 3: Updating graph objects with final beliefs...
#   X10 KL divergence: 0.009585
#
#  Testing seed 43, clip_fraction=0.1300...
# Adding variables to graph...
# BP Stage 1: Converting graph to numerical representation...
# BP Stage 2: Running BP iterations...
# BP Stage 3: Updating graph objects with final beliefs...
#   X10 KL divergence: 0.005046
#
#  Testing seed 43, clip_fraction=0.1350...
# Adding variables to graph...
# BP Stage 1: Converting graph to numerical representation...
# BP Stage 2: Running BP iterations...
# BP Stage 3: Updating graph objects with final beliefs...
#   X10 KL divergence: 0.004634
#
#  Testing seed 43, clip_fraction=0.1400...
# Adding variables to graph...
# BP Stage 1: Converting graph to numerical representation...
# BP Stage 2: Running BP iterations...
# BP Stage 3: Updating graph objects with final beliefs...
#   X10 KL divergence: 0.003299
#
#  Testing seed 43, clip_fraction=0.1450...
# Adding variables to graph...
# BP Stage 1: Converting graph to numerical representation...
# BP Stage 2: Running BP iterations...
# BP Stage 3: Updating graph objects with final beliefs...
#   X10 KL divergence: 0.000704
#
#  Testing seed 43, clip_fraction=0.1500...
# Adding variables to graph...
# BP Stage 1: Converting graph to numerical representation...
# BP Stage 2: Running BP iterations...
# BP Stage 3: Updating graph objects with final beliefs...
#   X10 KL divergence: 0.000710
#
#  Testing seed 43, clip_fraction=0.1550...
# Adding variables to graph...
# BP Stage 1: Converting graph to numerical representation...
# BP Stage 2: Running BP iterations...
# BP Stage 3: Updating graph objects with final beliefs...
#   X10 KL divergence: 0.017449
#
#  Testing seed 43, clip_fraction=0.1600...
# Adding variables to graph...
# BP Stage 1: Converting graph to numerical representation...
# BP Stage 2: Running BP iterations...
# BP Stage 3: Updating graph objects with final beliefs...
#   X10 KL divergence: 0.002775
#
#  Testing seed 43, clip_fraction=0.1650...
# Adding variables to graph...
# BP Stage 1: Converting graph to numerical representation...
# BP Stage 2: Running BP iterations...
# BP Stage 3: Updating graph objects with final beliefs...
#   X10 KL divergence: 0.029418
#
#  Testing seed 43, clip_fraction=0.1700...
# Adding variables to graph...
# BP Stage 1: Converting graph to numerical representation...
# BP Stage 2: Running BP iterations...
# BP Stage 3: Updating graph objects with final beliefs...
#   X10 KL divergence: 0.020289
#
#  Testing seed 43, clip_fraction=0.1750...
# Adding variables to graph...
# BP Stage 1: Converting graph to numerical representation...
# BP Stage 2: Running BP iterations...
# BP Stage 3: Updating graph objects with final beliefs...
#   X10 KL divergence: 0.010973
#
#  Testing seed 43, clip_fraction=0.1800...
# Adding variables to graph...
# BP Stage 1: Converting graph to numerical representation...
# BP Stage 2: Running BP iterations...
# BP Stage 3: Updating graph objects with final beliefs...
#   X10 KL divergence: 0.004068
#
#  Testing seed 43, clip_fraction=0.1850...
# Adding variables to graph...
# BP Stage 1: Converting graph to numerical representation...
# BP Stage 2: Running BP iterations...
# BP Stage 3: Updating graph objects with final beliefs...
#   X10 KL divergence: 0.002820
#
#  Testing seed 43, clip_fraction=0.1900...
# Adding variables to graph...
# BP Stage 1: Converting graph to numerical representation...
# BP Stage 2: Running BP iterations...
# BP Stage 3: Updating graph objects with final beliefs...
#   X10 KL divergence: 0.002071
#
#  Testing seed 43, clip_fraction=0.1950...
# Adding variables to graph...
# BP Stage 1: Converting graph to numerical representation...
# BP Stage 2: Running BP iterations...
# BP Stage 3: Updating graph objects with final beliefs...
#   X10 KL divergence: 0.004075
#
#  Testing seed 43, clip_fraction=0.2000...
# Adding variables to graph...
# BP Stage 1: Converting graph to numerical representation...
# BP Stage 2: Running BP iterations...
# BP Stage 3: Updating graph objects with final beliefs...
#   X10 KL divergence: 0.001766
#
#  Testing seed 43, clip_fraction=0.2050...
# Adding variables to graph...
# BP Stage 1: Converting graph to numerical representation...
# BP Stage 2: Running BP iterations...
# BP Stage 3: Updating graph objects with final beliefs...
#   X10 KL divergence: 0.002839
#
#  Testing seed 43, clip_fraction=0.2100...
# Adding variables to graph...
# BP Stage 1: Converting graph to numerical representation...
# BP Stage 2: Running BP iterations...
# BP Stage 3: Updating graph objects with final beliefs...
#   X10 KL divergence: 0.001261
#
#  Testing seed 43, clip_fraction=0.2150...
# Adding variables to graph...
# BP Stage 1: Converting graph to numerical representation...
# BP Stage 2: Running BP iterations...
# BP Stage 3: Updating graph objects with final beliefs...
#   X10 KL divergence: 0.002598
#
#  Testing seed 43, clip_fraction=0.2200...
# Adding variables to graph...
# BP Stage 1: Converting graph to numerical representation...
# BP Stage 2: Running BP iterations...
# BP Stage 3: Updating graph objects with final beliefs...
#   X10 KL divergence: 0.003769
#
#  Testing seed 43, clip_fraction=0.2250...
# Adding variables to graph...
# BP Stage 1: Converting graph to numerical representation...
# BP Stage 2: Running BP iterations...
# BP Stage 3: Updating graph objects with final beliefs...
#   X10 KL divergence: 0.007603
#
#  Testing seed 43, clip_fraction=0.2300...
# Adding variables to graph...
# BP Stage 1: Converting graph to numerical representation...
# BP Stage 2: Running BP iterations...
# BP Stage 3: Updating graph objects with final beliefs...
#   X10 KL divergence: 0.000821
#
#  Testing seed 43, clip_fraction=0.2350...
# Adding variables to graph...
# BP Stage 1: Converting graph to numerical representation...
# BP Stage 2: Running BP iterations...
# BP Stage 3: Updating graph objects with final beliefs...
#   X10 KL divergence: 0.004115
#
#  Testing seed 43, clip_fraction=0.2400...
# Adding variables to graph...
# BP Stage 1: Converting graph to numerical representation...
# BP Stage 2: Running BP iterations...
# BP Stage 3: Updating graph objects with final beliefs...
#   X10 KL divergence: 0.003475
#
#  Testing seed 43, clip_fraction=0.2450...
# Adding variables to graph...
# BP Stage 1: Converting graph to numerical representation...
# BP Stage 2: Running BP iterations...
# BP Stage 3: Updating graph objects with final beliefs...
#   X10 KL divergence: 0.002684
#
#  Testing seed 43, clip_fraction=0.2500...
# Adding variables to graph...
# BP Stage 1: Converting graph to numerical representation...
# BP Stage 2: Running BP iterations...
# BP Stage 3: Updating graph objects with final beliefs...
#   X10 KL divergence: 0.002670
#
#  Testing seed 43, clip_fraction=0.2550...
# Adding variables to graph...
# BP Stage 1: Converting graph to numerical representation...
# BP Stage 2: Running BP iterations...
# BP Stage 3: Updating graph objects with final beliefs...
#   X10 KL divergence: 0.017273
#
#  Testing seed 43, clip_fraction=0.2600...
# Adding variables to graph...
# BP Stage 1: Converting graph to numerical representation...
# BP Stage 2: Running BP iterations...
# BP Stage 3: Updating graph objects with final beliefs...
#   X10 KL divergence: 0.044303
#
#  Testing seed 43, clip_fraction=0.2650...
# Adding variables to graph...
# BP Stage 1: Converting graph to numerical representation...
# BP Stage 2: Running BP iterations...
# BP Stage 3: Updating graph objects with final beliefs...
#   X10 KL divergence: 0.070044
#
#  Testing seed 43, clip_fraction=0.2700...
# Adding variables to graph...
# BP Stage 1: Converting graph to numerical representation...
# BP Stage 2: Running BP iterations...
# BP Stage 3: Updating graph objects with final beliefs...
#   X10 KL divergence: 0.009956
#
#  Testing seed 43, clip_fraction=0.2750...
# Adding variables to graph...
# BP Stage 1: Converting graph to numerical representation...
# BP Stage 2: Running BP iterations...
# BP Stage 3: Updating graph objects with final beliefs...
#   X10 KL divergence: 0.031273
#
#  Testing seed 43, clip_fraction=0.2800...
# Adding variables to graph...
# BP Stage 1: Converting graph to numerical representation...
# BP Stage 2: Running BP iterations...
# BP Stage 3: Updating graph objects with final beliefs...
#   X10 KL divergence: 0.048800
#
#  Testing seed 43, clip_fraction=0.2850...
# Adding variables to graph...
# BP Stage 1: Converting graph to numerical representation...
# BP Stage 2: Running BP iterations...
# BP Stage 3: Updating graph objects with final beliefs...
#   X10 KL divergence: 0.018054
#
#  Testing seed 43, clip_fraction=0.2900...
# Adding variables to graph...
# BP Stage 1: Converting graph to numerical representation...
# BP Stage 2: Running BP iterations...
# BP Stage 3: Updating graph objects with final beliefs...
#   X10 KL divergence: 0.015505
#
#  Testing seed 43, clip_fraction=0.2950...
# Adding variables to graph...
# BP Stage 1: Converting graph to numerical representation...
# BP Stage 2: Running BP iterations...
# BP Stage 3: Updating graph objects with final beliefs...
#   X10 KL divergence: 0.022305
#
#  Testing seed 43, clip_fraction=0.3000...
# Adding variables to graph...
# BP Stage 1: Converting graph to numerical representation...
# BP Stage 2: Running BP iterations...
# BP Stage 3: Updating graph objects with final beliefs...
#   X10 KL divergence: 0.119038
#
#  Testing seed 43, clip_fraction=0.3050...
# Adding variables to graph...
# BP Stage 1: Converting graph to numerical representation...
# BP Stage 2: Running BP iterations...
# BP Stage 3: Updating graph objects with final beliefs...
#   X10 KL divergence: 0.031164
#
#  Testing seed 43, clip_fraction=0.3100...
# Adding variables to graph...
# BP Stage 1: Converting graph to numerical representation...
# BP Stage 2: Running BP iterations...
# BP Stage 3: Updating graph objects with final beliefs...
#   X10 KL divergence: 0.255530
#
#  Testing seed 43, clip_fraction=0.3150...
# Adding variables to graph...
# BP Stage 1: Converting graph to numerical representation...
# BP Stage 2: Running BP iterations...
# BP Stage 3: Updating graph objects with final beliefs...
#   X10 KL divergence: 0.092854
#
#  Testing seed 43, clip_fraction=0.3200...
# Adding variables to graph...
# BP Stage 1: Converting graph to numerical representation...
# BP Stage 2: Running BP iterations...
# BP Stage 3: Updating graph objects with final beliefs...
#   X10 KL divergence: 0.038083
#
#  Testing seed 43, clip_fraction=0.3250...
# Adding variables to graph...
# BP Stage 1: Converting graph to numerical representation...
# BP Stage 2: Running BP iterations...
# BP Stage 3: Updating graph objects with final beliefs...
#   X10 KL divergence: 0.314976
#
#  Testing seed 43, clip_fraction=0.3300...
# Adding variables to graph...
# BP Stage 1: Converting graph to numerical representation...
# BP Stage 2: Running BP iterations...
# BP Stage 3: Updating graph objects with final beliefs...
#   X10 KL divergence: 0.186859
#
#  Testing seed 43, clip_fraction=0.3350...
# Adding variables to graph...
# BP Stage 1: Converting graph to numerical representation...
# BP Stage 2: Running BP iterations...
# BP Stage 3: Updating graph objects with final beliefs...
#   X10 KL divergence: 0.043868
#
#  Testing seed 43, clip_fraction=0.3400...
# Adding variables to graph...
# BP Stage 1: Converting graph to numerical representation...
# BP Stage 2: Running BP iterations...
# BP Stage 3: Updating graph objects with final beliefs...
#   X10 KL divergence: 0.200614
#
#  Testing seed 43, clip_fraction=0.3450...
# Adding variables to graph...
# BP Stage 1: Converting graph to numerical representation...
# BP Stage 2: Running BP iterations...
# BP Stage 3: Updating graph objects with final beliefs...
#   X10 KL divergence: 0.205733
#
#  Testing seed 43, clip_fraction=0.3500...
# Adding variables to graph...
# BP Stage 1: Converting graph to numerical representation...
# BP Stage 2: Running BP iterations...
# BP Stage 3: Updating graph objects with final beliefs...
#   X10 KL divergence: 0.111120
#
#  Testing seed 43, clip_fraction=0.3550...
# Adding variables to graph...
# BP Stage 1: Converting graph to numerical representation...
# BP Stage 2: Running BP iterations...
# BP Stage 3: Updating graph objects with final beliefs...
#   X10 KL divergence: 0.123010
#
#  Testing seed 43, clip_fraction=0.3600...
# Adding variables to graph...
# BP Stage 1: Converting graph to numerical representation...
# BP Stage 2: Running BP iterations...
# BP Stage 3: Updating graph objects with final beliefs...
#   X10 KL divergence: 0.305144
#
#  Testing seed 43, clip_fraction=0.3650...
# Adding variables to graph...
# BP Stage 1: Converting graph to numerical representation...
# BP Stage 2: Running BP iterations...
# BP Stage 3: Updating graph objects with final beliefs...
#   X10 KL divergence: 0.152522
#
#  Testing seed 43, clip_fraction=0.3700...
# Adding variables to graph...
# BP Stage 1: Converting graph to numerical representation...
# BP Stage 2: Running BP iterations...
# BP Stage 3: Updating graph objects with final beliefs...
#   X10 KL divergence: 0.251549
#
#  Testing seed 43, clip_fraction=0.3750...
# Adding variables to graph...
# BP Stage 1: Converting graph to numerical representation...
# BP Stage 2: Running BP iterations...
# BP Stage 3: Updating graph objects with final beliefs...
#   X10 KL divergence: 0.203299
#
#  Testing seed 43, clip_fraction=0.3800...
# Adding variables to graph...
# BP Stage 1: Converting graph to numerical representation...
# BP Stage 2: Running BP iterations...
# BP Stage 3: Updating graph objects with final beliefs...
#   X10 KL divergence: 0.036278
#
#  Testing seed 43, clip_fraction=0.3850...
# Adding variables to graph...
# BP Stage 1: Converting graph to numerical representation...
# BP Stage 2: Running BP iterations...
# BP Stage 3: Updating graph objects with final beliefs...
#   X10 KL divergence: 0.273478
#
#  Testing seed 43, clip_fraction=0.3900...
# Adding variables to graph...
# BP Stage 1: Converting graph to numerical representation...
# BP Stage 2: Running BP iterations...
# BP Stage 3: Updating graph objects with final beliefs...
#   X10 KL divergence: 0.241721
#
#  Testing seed 43, clip_fraction=0.3950...
# Adding variables to graph...
# BP Stage 1: Converting graph to numerical representation...
# BP Stage 2: Running BP iterations...
# BP Stage 3: Updating graph objects with final beliefs...
#   X10 KL divergence: 0.176593
#
#  Testing seed 43, clip_fraction=0.4000...
# Adding variables to graph...
# BP Stage 1: Converting graph to numerical representation...
# BP Stage 2: Running BP iterations...
# BP Stage 3: Updating graph objects with final beliefs...
#   X10 KL divergence: 0.194713
#
#  Testing seed 43, clip_fraction=0.4050...
# Adding variables to graph...
# BP Stage 1: Converting graph to numerical representation...
# BP Stage 2: Running BP iterations...
# BP Stage 3: Updating graph objects with final beliefs...
#   X10 KL divergence: 0.515350
#
#  Testing seed 43, clip_fraction=0.4100...
# Adding variables to graph...
# BP Stage 1: Converting graph to numerical representation...
# BP Stage 2: Running BP iterations...
# BP Stage 3: Updating graph objects with final beliefs...
#   X10 KL divergence: 0.337630
#
#  Testing seed 43, clip_fraction=0.4150...
# Adding variables to graph...
# BP Stage 1: Converting graph to numerical representation...
# BP Stage 2: Running BP iterations...
# BP Stage 3: Updating graph objects with final beliefs...
#   X10 KL divergence: 0.291671
#
#  Testing seed 43, clip_fraction=0.4200...
# Adding variables to graph...
# BP Stage 1: Converting graph to numerical representation...
# BP Stage 2: Running BP iterations...
# BP Stage 3: Updating graph objects with final beliefs...
#   X10 KL divergence: 0.311342
#
#  Testing seed 43, clip_fraction=0.4250...
# Adding variables to graph...
# BP Stage 1: Converting graph to numerical representation...
# BP Stage 2: Running BP iterations...
# BP Stage 3: Updating graph objects with final beliefs...
#   X10 KL divergence: 0.149867
#
#  Testing seed 43, clip_fraction=0.4300...
# Adding variables to graph...
# BP Stage 1: Converting graph to numerical representation...
# BP Stage 2: Running BP iterations...
# BP Stage 3: Updating graph objects with final beliefs...
#   X10 KL divergence: 0.284762
#
# ...
#
#  Testing seed 91, clip_fraction=0.1900...
# Adding variables to graph...
# BP Stage 1: Converting graph to numerical representation...
# BP Stage 2: Running BP iterations...
# BP Stage 3: Updating graph objects with final beliefs...
#   X10 KL divergence: 0.001200
#
#  Testing seed 91, clip_fraction=0.1950...
# Adding variables to graph...
# BP Stage 1: Converting graph to numerical representation...
# BP Stage 2: Running BP iterations...
# BP Stage 3: Updating graph objects with final beliefs...
#   X10 KL divergence: 0.002439
#
#  Testing seed 91, clip_fraction=0.2000...
# Adding variables to graph...
# BP Stage 1: Converting graph to numerical representation...
# BP Stage 2: Running BP iterations...
# BP Stage 3: Updating graph objects with final beliefs...
#   X10 KL divergence: 0.310828
#
#  Testing seed 91, clip_fraction=0.2050...
# Adding variables to graph...
# BP Stage 1: Converting graph to numerical representation...
# BP Stage 2: Running BP iterations...
# BP Stage 3: Updating graph objects with final beliefs...
#   X10 KL divergence: 0.000951
#
#  Testing seed 91, clip_fraction=0.2100...
# Adding variables to graph...
# BP Stage 1: Converting graph to numerical representation...
# BP Stage 2: Running BP iterations...
# BP Stage 3: Updating graph objects with final beliefs...
#   X10 KL divergence: 0.109902
#
#  Testing seed 91, clip_fraction=0.2150...
# Adding variables to graph...
# BP Stage 1: Converting graph to numerical representation...
# BP Stage 2: Running BP iterations...
# BP Stage 3: Updating graph objects with final beliefs...
#   X10 KL divergence: 0.001234
#
#  Testing seed 91, clip_fraction=0.2200...
# Adding variables to graph...
# BP Stage 1: Converting graph to numerical representation...
# BP Stage 2: Running BP iterations...
# BP Stage 3: Updating graph objects with final beliefs...
#   X10 KL divergence: 0.019400
#
#  Testing seed 91, clip_fraction=0.2250...
# Adding variables to graph...
# BP Stage 1: Converting graph to numerical representation...
# BP Stage 2: Running BP iterations...
# BP Stage 3: Updating graph objects with final beliefs...
#   X10 KL divergence: 0.098004
#
#  Testing seed 91, clip_fraction=0.2300...
# Adding variables to graph...
# BP Stage 1: Converting graph to numerical representation...
# BP Stage 2: Running BP iterations...
# BP Stage 3: Updating graph objects with final beliefs...
#   X10 KL divergence: 0.053174
#
#  Testing seed 91, clip_fraction=0.2350...
# Adding variables to graph...
# BP Stage 1: Converting graph to numerical representation...
# BP Stage 2: Running BP iterations...
# BP Stage 3: Updating graph objects with final beliefs...
#   X10 KL divergence: 0.047372
#
#  Testing seed 91, clip_fraction=0.2400...
# Adding variables to graph...
# BP Stage 1: Converting graph to numerical representation...
# BP Stage 2: Running BP iterations...
# BP Stage 3: Updating graph objects with final beliefs...
#   X10 KL divergence: 0.004921
#
#  Testing seed 91, clip_fraction=0.2450...
# Adding variables to graph...
# BP Stage 1: Converting graph to numerical representation...
# BP Stage 2: Running BP iterations...
# BP Stage 3: Updating graph objects with final beliefs...
#   X10 KL divergence: 0.011897
#
#  Testing seed 91, clip_fraction=0.2500...
# Adding variables to graph...
# BP Stage 1: Converting graph to numerical representation...
# BP Stage 2: Running BP iterations...
# BP Stage 3: Updating graph objects with final beliefs...
#   X10 KL divergence: 0.004225
#
#  Testing seed 91, clip_fraction=0.2550...
# Adding variables to graph...
# BP Stage 1: Converting graph to numerical representation...
# BP Stage 2: Running BP iterations...
# BP Stage 3: Updating graph objects with final beliefs...
#   X10 KL divergence: 0.071425
#
#  Testing seed 91, clip_fraction=0.2600...
# Adding variables to graph...
# BP Stage 1: Converting graph to numerical representation...
# BP Stage 2: Running BP iterations...
# BP Stage 3: Updating graph objects with final beliefs...
#   X10 KL divergence: 0.002002
#
#  Testing seed 91, clip_fraction=0.2650...
# Adding variables to graph...
# BP Stage 1: Converting graph to numerical representation...
# BP Stage 2: Running BP iterations...
# BP Stage 3: Updating graph objects with final beliefs...
#   X10 KL divergence: 0.001439
#
#  Testing seed 91, clip_fraction=0.2700...
# Adding variables to graph...
# BP Stage 1: Converting graph to numerical representation...
# BP Stage 2: Running BP iterations...
# BP Stage 3: Updating graph objects with final beliefs...
#   X10 KL divergence: 0.265181
#
#  Testing seed 91, clip_fraction=0.2750...
# Adding variables to graph...
# BP Stage 1: Converting graph to numerical representation...
# BP Stage 2: Running BP iterations...
# BP Stage 3: Updating graph objects with final beliefs...
#   X10 KL divergence: 0.026304
#
#  Testing seed 91, clip_fraction=0.2800...
# Adding variables to graph...
# BP Stage 1: Converting graph to numerical representation...
# BP Stage 2: Running BP iterations...
# BP Stage 3: Updating graph objects with final beliefs...
#   X10 KL divergence: 0.005951
#
#  Testing seed 91, clip_fraction=0.2850...
# Adding variables to graph...
# BP Stage 1: Converting graph to numerical representation...
# BP Stage 2: Running BP iterations...
# BP Stage 3: Updating graph objects with final beliefs...
#   X10 KL divergence: 0.371175
#
#  Testing seed 91, clip_fraction=0.2900...
# Adding variables to graph...
# BP Stage 1: Converting graph to numerical representation...
# BP Stage 2: Running BP iterations...
# BP Stage 3: Updating graph objects with final beliefs...
#   X10 KL divergence: 0.080733
#
#  Testing seed 91, clip_fraction=0.2950...
# Adding variables to graph...
# BP Stage 1: Converting graph to numerical representation...
# BP Stage 2: Running BP iterations...
# BP Stage 3: Updating graph objects with final beliefs...
#   X10 KL divergence: 0.012919
#
#  Testing seed 91, clip_fraction=0.3000...
# Adding variables to graph...
# BP Stage 1: Converting graph to numerical representation...
# BP Stage 2: Running BP iterations...
# BP Stage 3: Updating graph objects with final beliefs...
#   X10 KL divergence: 0.061836
#
#  Testing seed 91, clip_fraction=0.3050...
# Adding variables to graph...
# BP Stage 1: Converting graph to numerical representation...
# BP Stage 2: Running BP iterations...
# BP Stage 3: Updating graph objects with final beliefs...
#   X10 KL divergence: 0.026754
#
#  Testing seed 91, clip_fraction=0.3100...
# Adding variables to graph...
# BP Stage 1: Converting graph to numerical representation...
# BP Stage 2: Running BP iterations...
# BP Stage 3: Updating graph objects with final beliefs...
#   X10 KL divergence: 0.066167
#
#  Testing seed 91, clip_fraction=0.3150...
# Adding variables to graph...
# BP Stage 1: Converting graph to numerical representation...
# BP Stage 2: Running BP iterations...
# BP Stage 3: Updating graph objects with final beliefs...
#   X10 KL divergence: 0.051030
#
#  Testing seed 91, clip_fraction=0.3200...
# Adding variables to graph...
# BP Stage 1: Converting graph to numerical representation...
# BP Stage 2: Running BP iterations...
# BP Stage 3: Updating graph objects with final beliefs...
#   X10 KL divergence: 0.013167
#
#  Testing seed 91, clip_fraction=0.3250...
# Adding variables to graph...
# BP Stage 1: Converting graph to numerical representation...
# BP Stage 2: Running BP iterations...
# BP Stage 3: Updating graph objects with final beliefs...
#   X10 KL divergence: 0.139693
#
#  Testing seed 91, clip_fraction=0.3300...
# Adding variables to graph...
# BP Stage 1: Converting graph to numerical representation...
# BP Stage 2: Running BP iterations...
# BP Stage 3: Updating graph objects with final beliefs...
#   X10 KL divergence: 0.304980
#
#  Testing seed 91, clip_fraction=0.3350...
# Adding variables to graph...
# BP Stage 1: Converting graph to numerical representation...
# BP Stage 2: Running BP iterations...
# BP Stage 3: Updating graph objects with final beliefs...
#   X10 KL divergence: 0.065162
#
#  Testing seed 91, clip_fraction=0.3400...
# Adding variables to graph...
# BP Stage 1: Converting graph to numerical representation...
# BP Stage 2: Running BP iterations...
# BP Stage 3: Updating graph objects with final beliefs...
#   X10 KL divergence: 0.058191
#
#  Testing seed 91, clip_fraction=0.3450...
# Adding variables to graph...
# BP Stage 1: Converting graph to numerical representation...
# BP Stage 2: Running BP iterations...
# BP Stage 3: Updating graph objects with final beliefs...
#   X10 KL divergence: 0.248107
#
#  Testing seed 91, clip_fraction=0.3500...
# Adding variables to graph...
# BP Stage 1: Converting graph to numerical representation...
# BP Stage 2: Running BP iterations...
# BP Stage 3: Updating graph objects with final beliefs...
#   X10 KL divergence: 0.337403
#
#  Testing seed 91, clip_fraction=0.3550...
# Adding variables to graph...
# BP Stage 1: Converting graph to numerical representation...
# BP Stage 2: Running BP iterations...
# BP Stage 3: Updating graph objects with final beliefs...
#   X10 KL divergence: 0.391452
#
#  Testing seed 91, clip_fraction=0.3600...
# Adding variables to graph...
# BP Stage 1: Converting graph to numerical representation...
# BP Stage 2: Running BP iterations...
# BP Stage 3: Updating graph objects with final beliefs...
#   X10 KL divergence: 0.040399
#
#  Testing seed 91, clip_fraction=0.3650...
# Adding variables to graph...
# BP Stage 1: Converting graph to numerical representation...
# BP Stage 2: Running BP iterations...
# BP Stage 3: Updating graph objects with final beliefs...
#   X10 KL divergence: 0.303746
#
#  Testing seed 91, clip_fraction=0.3700...
# Adding variables to graph...
# BP Stage 1: Converting graph to numerical representation...
# BP Stage 2: Running BP iterations...
# BP Stage 3: Updating graph objects with final beliefs...
#   X10 KL divergence: 0.251154
#
#  Testing seed 91, clip_fraction=0.3750...
# Adding variables to graph...
# BP Stage 1: Converting graph to numerical representation...
# BP Stage 2: Running BP iterations...
# BP Stage 3: Updating graph objects with final beliefs...
#   X10 KL divergence: 0.366616
#
#  Testing seed 91, clip_fraction=0.3800...
# Adding variables to graph...
# BP Stage 1: Converting graph to numerical representation...
# BP Stage 2: Running BP iterations...
# BP Stage 3: Updating graph objects with final beliefs...
#   X10 KL divergence: 0.117755
#
#  Testing seed 91, clip_fraction=0.3850...
# Adding variables to graph...
# BP Stage 1: Converting graph to numerical representation...
# BP Stage 2: Running BP iterations...
# BP Stage 3: Updating graph objects with final beliefs...
#   X10 KL divergence: 0.312585
#
#  Testing seed 91, clip_fraction=0.3900...
# Adding variables to graph...
# BP Stage 1: Converting graph to numerical representation...
# BP Stage 2: Running BP iterations...
# BP Stage 3: Updating graph objects with final beliefs...
#   X10 KL divergence: 0.067395
#
#  Testing seed 91, clip_fraction=0.3950...
# Adding variables to graph...
# BP Stage 1: Converting graph to numerical representation...
# BP Stage 2: Running BP iterations...
# BP Stage 3: Updating graph objects with final beliefs...
#   X10 KL divergence: 0.188374
#
#  Testing seed 91, clip_fraction=0.4000...
# Adding variables to graph...
# BP Stage 1: Converting graph to numerical representation...
# BP Stage 2: Running BP iterations...
# BP Stage 3: Updating graph objects with final beliefs...
#   X10 KL divergence: 0.110605
#
#  Testing seed 91, clip_fraction=0.4050...
# Adding variables to graph...
# BP Stage 1: Converting graph to numerical representation...
# BP Stage 2: Running BP iterations...
# BP Stage 3: Updating graph objects with final beliefs...
#   X10 KL divergence: 0.159890
#
#  Testing seed 91, clip_fraction=0.4100...
# Adding variables to graph...
# BP Stage 1: Converting graph to numerical representation...
# BP Stage 2: Running BP iterations...
# BP Stage 3: Updating graph objects with final beliefs...
#   X10 KL divergence: 0.283029
#
#  Testing seed 91, clip_fraction=0.4150...
# Adding variables to graph...
# BP Stage 1: Converting graph to numerical representation...
# BP Stage 2: Running BP iterations...
# BP Stage 3: Updating graph objects with final beliefs...
#   X10 KL divergence: 0.095832
#
#  Testing seed 91, clip_fraction=0.4200...
# Adding variables to graph...
# BP Stage 1: Converting graph to numerical representation...
# BP Stage 2: Running BP iterations...
# BP Stage 3: Updating graph objects with final beliefs...
#   X10 KL divergence: 0.138762
#
#  Testing seed 91, clip_fraction=0.4250...
# Adding variables to graph...
# BP Stage 1: Converting graph to numerical representation...
# BP Stage 2: Running BP iterations...
# BP Stage 3: Updating graph objects with final beliefs...
#   X10 KL divergence: 0.089580
#
#  Testing seed 91, clip_fraction=0.4300...
# Adding variables to graph...
# BP Stage 1: Converting graph to numerical representation...
# BP Stage 2: Running BP iterations...
# BP Stage 3: Updating graph objects with final beliefs...
#   X10 KL divergence: 0.204535
#
#  Testing seed 91, clip_fraction=0.4350...
# Adding variables to graph...
# BP Stage 1: Converting graph to numerical representation...
# BP Stage 2: Running BP iterations...
# BP Stage 3: Updating graph objects with final beliefs...
#   X10 KL divergence: 0.370656
#
#  Testing seed 91, clip_fraction=0.4400...
# Adding variables to graph...
# BP Stage 1: Converting graph to numerical representation...
# BP Stage 2: Running BP iterations...
# BP Stage 3: Updating graph objects with final beliefs...
#   X10 KL divergence: 0.067974
#
#  Testing seed 91, clip_fraction=0.4450...
# Adding variables to graph...
# BP Stage 1: Converting graph to numerical representation...
# BP Stage 2: Running BP iterations...
# BP Stage 3: Updating graph objects with final beliefs...
#   X10 KL divergence: 0.195389
#
#  Testing seed 91, clip_fraction=0.4500...
# Adding variables to graph...
# BP Stage 1: Converting graph to numerical representation...
# BP Stage 2: Running BP iterations...
# BP Stage 3: Updating graph objects with final beliefs...
#   X10 KL divergence: 0.211399
#
#  Testing seed 91, clip_fraction=0.4550...
# Adding variables to graph...
# BP Stage 1: Converting graph to numerical representation...
# BP Stage 2: Running BP iterations...
# BP Stage 3: Updating graph objects with final beliefs...
#   X10 KL divergence: 0.137359
#
#  Testing seed 91, clip_fraction=0.4600...
# Adding variables to graph...
# BP Stage 1: Converting graph to numerical representation...
# BP Stage 2: Running BP iterations...
# BP Stage 3: Updating graph objects with final beliefs...
#   X10 KL divergence: 0.205115
#
#  Testing seed 91, clip_fraction=0.4650...
# Adding variables to graph...
# BP Stage 1: Converting graph to numerical representation...
# BP Stage 2: Running BP iterations...
# BP Stage 3: Updating graph objects with final beliefs...
#   X10 KL divergence: 0.092941
#
#  Testing seed 91, clip_fraction=0.4700...
# Adding variables to graph...
# BP Stage 1: Converting graph to numerical representation...
# BP Stage 2: Running BP iterations...
# BP Stage 3: Updating graph objects with final beliefs...
#   X10 KL divergence: 0.172653
#
#  Testing seed 91, clip_fraction=0.4750...
# Adding variables to graph...
# BP Stage 1: Converting graph to numerical representation...
# BP Stage 2: Running BP iterations...
# BP Stage 3: Updating graph objects with final beliefs...
#   X10 KL divergence: 0.113868
#
#  Testing seed 91, clip_fraction=0.4800...
# Adding variables to graph...
# BP Stage 1: Converting graph to numerical representation...
# BP Stage 2: Running BP iterations...
# BP Stage 3: Updating graph objects with final beliefs...
#   X10 KL divergence: 0.182960
#
#  Testing seed 91, clip_fraction=0.4850...
# Adding variables to graph...
# BP Stage 1: Converting graph to numerical representation...
# BP Stage 2: Running BP iterations...
# BP Stage 3: Updating graph objects with final beliefs...
#   X10 KL divergence: 0.633347
#
#  Testing seed 91, clip_fraction=0.4900...
# Adding variables to graph...
# BP Stage 1: Converting graph to numerical representation...
# BP Stage 2: Running BP iterations...
# BP Stage 3: Updating graph objects with final beliefs...
#   X10 KL divergence: 0.629105
#
#  Testing seed 91, clip_fraction=0.4950...
# Adding variables to graph...
# BP Stage 1: Converting graph to numerical representation...
# BP Stage 2: Running BP iterations...
# BP Stage 3: Updating graph objects with final beliefs...
#   X10 KL divergence: 1.101392
#
# Experiment complete!
# Mean KL divergence across all seeds: 0.104655
# Std KL divergence across all seeds: 0.169628

# %%
# Cell 4: Visualize Prior Distributions for Different n Values
fig, axes = plt.subplots(2, 4, figsize=(14, 8))
axes = axes.flatten()
clip_fractions_to_plot, idx_to_plot = sample_evenly(clip_fractions, 8)  # Select first 8 clip fractions`` for plotting

# np.random.seed(seed_for_visualisation)
# prior = create_uniform_perturbed_by_white_noise(1)

for idx, clip_frac in enumerate(clip_fractions_to_plot):
    # Create the mixture prior
    test_prior = create_clipped_uniform(clip_frac)
    prior_entropy = calculate_entropy_bit(test_prior)
    
    # if n > 100:
    #     # compute in log space to avoid numerical issues
    #     log_test_prior = n * np.log(prior + 1e-300)  # Add small value to avoid log(0)
    #     test_prior = np.exp(log_test_prior - np.max(log_test_prior))  # Subtract max for numerical stability
    # else:
    #     test_prior = prior**n
    # test_prior = dm.normalise(test_prior)
    # prior_entropy = calculate_entropy_bit(test_prior)

    # Plot
    axes[idx].bar(range(cfg.belief_discretisation), test_prior, color='steelblue', alpha=0.7, edgecolor='black', linewidth=0.5)
    axes[idx].set_title(f'Clip Fraction = {clip_frac:.3f}\nEntropy = {prior_entropy:.3f} bits', fontsize=11, fontweight='bold')
    axes[idx].set_xlabel('Bin Index', fontsize=10)
    axes[idx].set_ylabel('Probability', fontsize=10)
    axes[idx].grid(True, alpha=0.3, axis='y')

plt.suptitle('Prior Distributions: Clipped Uniform', 
             fontsize=14, fontweight='bold', y=1.00)
plt.tight_layout()
plt.show()

# %%
# Cell 5: Visualise Converged Beliefs
fig, axes = plt.subplots(2, 4, figsize=(14, 8))
axes = axes.flatten()
final_beliefs_to_plot = np.stack(final_beliefs_x10, axis=0)[idx_to_plot]  # Select first 8 beliefs for plotting

for idx, (clip_frac, belief) in enumerate(zip(clip_fractions_to_plot, final_beliefs_to_plot)):
    # Plot the belief distribution
    axes[idx].plot(cfg.measurement_range, belief, linewidth=2, color='steelblue')
    axes[idx].fill_between(cfg.measurement_range, belief, alpha=0.3, color='steelblue')
    axes[idx].set_title(f'Clip Fraction = {clip_frac:.3f} | KL = {kl_divergences[idx_to_plot[idx]]:.4f}', fontsize=11, fontweight='bold')
    axes[idx].set_xlabel('Disparity Value', fontsize=10)
    axes[idx].set_ylabel('Probability', fontsize=10)
    axes[idx].grid(True, alpha=0.3)
    axes[idx].set_xlim([cfg.min_measurement, cfg.max_measurement])

plt.suptitle(f'Converged Belief of X10 for Each n Value', 
             fontsize=14, fontweight='bold', y=1.00)
plt.tight_layout()
plt.show()

# %%
# Cell 6: Plot KL Divergence vs n Values

# Plot 1: KL divergence vs n
fig, ax = plt.subplots(1, 1, figsize=(12, 10))

# calculate entropy for each n value
# entropy_values = np.array([calculate_entropy_bit(create_uniform_perturbed_by_white_noise(n)) for n in n_samples])

# Calculate mean and std across seeds
mean_kl = np.mean(all_kl_divergences, axis=0)
std_kl = np.std(all_kl_divergences, axis=0)

# n-values: plot mean with shaded std deviation
ax.plot(clip_fractions, mean_kl, 'o-', linewidth=2, markersize=8, label='Mean KL Divergence')
ax.fill_between(clip_fractions, mean_kl - std_kl, mean_kl + std_kl, alpha=0.2)

ax.set_xlabel('Clip Fraction', fontsize=12)
ax.set_ylabel('KL Divergence from Gaussian', fontsize=12)
ax.set_title('KL Divergence of X10 Belief vs Clip Fraction', fontsize=14, fontweight='bold')
ax.set_xscale("log")

ax.set_ylim(bottom=0)
ax.grid(True, alpha=0.3)
ax.legend(fontsize=11)

# clip_fraction-values: plot formatting
from matplotlib.ticker import LogLocator, NullFormatter, FuncFormatter
clip_fractions_nonzero = clip_fractions[clip_fractions > 0]
min_clip = float(np.min(clip_fractions_nonzero))
max_clip = float(np.max(clip_fractions))
decades = np.arange(np.floor(np.log10(min_clip)), np.ceil(np.log10(max_clip)) + 1)
# Major ticks at powers of 10
ax.set_xticks(10**decades)
# Minor ticks between decades (no labels)
ax.xaxis.set_minor_locator(LogLocator(base=10.0, subs=np.arange(2, 10) * 0.1))
ax.xaxis.set_minor_formatter(NullFormatter())

# Readable labels: more precision below 1, one decimal above
ax.xaxis.set_major_formatter(FuncFormatter(lambda x, pos: f'{x:.3f}' if x < 1 else f'{x:.1f}'))

plt.tight_layout()
plt.show()

# %%
# Cell 7: Plot KL Divergence vs Prior Entropy

# Plot 1: KL divergence vs n
fig, ax = plt.subplots(1, 1, figsize=(12, 10))

# Calculate mean and std across seeds
mean_kl = np.mean(all_kl_divergences, axis=0)
std_kl = np.std(all_kl_divergences, axis=0)
mean_entropy = np.mean(all_entropy_values, axis=0)

# entropy: plot mean with shaded std deviation
ax.plot(mean_entropy, mean_kl, 'o-', linewidth=2, markersize=8, label='Mean KL Divergence')
ax.fill_between(mean_entropy, mean_kl - std_kl, mean_kl + std_kl, alpha=0.2)

ax.set_xlabel('Prior Entropy (bits)', fontsize=12)
ax.set_ylabel('KL Divergence from Gaussian', fontsize=12)
ax.set_title(f'KL Divergence of X10 Belief vs Entropy of Prior', fontsize=14, fontweight='bold')

ax.set_ylim(bottom=0)
ax.grid(True, alpha=0.3)
ax.legend(fontsize=11)

plt.tight_layout()
plt.show()

# %%
# # Cell 8: Plot KL Divergence against Standard Deviation

# # Use stored standard deviation values & normalise by uniform distribution
# mean_std_dev = np.mean(np.square(all_std_dev_values), axis=0)
# uniform_std = (cfg.max_measurement - cfg.min_measurement)**2 / 12
# normalised_std_dev = mean_std_dev / uniform_std

# # Calculate mean and std across seeds
# mean_kl = np.mean(all_kl_divergences, axis=0)
# std_kl = np.std(all_kl_divergences, axis=0)

# # Sort by standard deviation to prevent zigzagging
# # sort_idx = np.argsort(normalised_std_dev)
# # normalised_std_dev = normalised_std_dev[sort_idx]
# # mean_kl = mean_kl[sort_idx]
# # std_kl = std_kl[sort_idx]
# normalised_std_dev = normalised_std_dev[::-1]
# mean_kl = mean_kl[::-1]
# std_kl = std_kl[::-1]


# # Plot KL divergence vs Standard Deviation
# fig, ax = plt.subplots(1, 1, figsize=(12, 10))

# # Plot mean with shaded std deviation
# ax.plot(normalised_std_dev, mean_kl, 'o-', linewidth=2, markersize=8, label='Mean KL Divergence', color='steelblue')
# ax.fill_between(normalised_std_dev, mean_kl - std_kl, mean_kl + std_kl, alpha=0.2, color='steelblue')

# ax.set_xlabel('Normalised Prior Variance (σ² / $σ²_{uniform}$)', fontsize=12)
# ax.set_ylabel('KL Divergence from Gaussian', fontsize=12)
# ax.set_title('KL Divergence of X10 Belief vs Prior Confidence (Variance)', fontsize=14, fontweight='bold')

# ax.set_xlim([0, 1.05])
# ax.set_ylim(bottom=0)
# # ax.set_yscale("log")
# ax.grid(True, alpha=0.3)
# ax.legend(fontsize=11)

# plt.tight_layout()
# plt.show()


# testing
# Cell 8: Plot KL Divergence against Standard Deviation

# Use stored standard deviation values & normalise by uniform distribution
mean_std_dev = np.mean(np.square(all_std_dev_values), axis=0)
uniform_std = (cfg.max_measurement - cfg.min_measurement)**2 / 12
normalised_std_dev = mean_std_dev / uniform_std
mean_kl = np.mean(all_kl_divergences, axis=0)
std_kl = np.std(all_kl_divergences, axis=0)

# Sort by standard deviation to prevent zigzagging
# sort_idx = np.argsort(normalised_std_dev)
# normalised_std_dev = normalised_std_dev[sort_idx]
# mean_kl = mean_kl[sort_idx]
# std_kl = std_kl[sort_idx]
normalised_std_dev_sorted = normalised_std_dev[::-1]
mean_kl_sorted = mean_kl[::-1]
std_kl_sorted = std_kl[::-1]

# Bin the data for smoother visualization
num_bins = 20
bin_edges = np.linspace(normalised_std_dev_sorted.min(), normalised_std_dev_sorted.max(), num_bins + 1)
bin_centers = (bin_edges[:-1] + bin_edges[1:]) / 2
binned_kl = []
binned_std = []

for i in range(num_bins):
    mask = (normalised_std_dev_sorted >= bin_edges[i]) & (normalised_std_dev_sorted < bin_edges[i+1])
    if np.any(mask):
        binned_kl.append(np.mean(mean_kl_sorted[mask]))
        binned_std.append(np.sqrt(np.mean(std_kl_sorted[mask]**2)))  # RMS of std devs
    else:
        binned_kl.append(np.nan)
        binned_std.append(np.nan)

binned_kl = np.array(binned_kl)
binned_std = np.array(binned_std)

# Remove NaN bins
valid_mask = ~np.isnan(binned_kl)
bin_centers = bin_centers[valid_mask]
binned_kl = binned_kl[valid_mask]
binned_std = binned_std[valid_mask]

# Plot KL divergence vs Standard Deviation
fig, ax = plt.subplots(1, 1, figsize=(12, 10))

# Plot binned data
ax.plot(bin_centers, binned_kl, 'o-', linewidth=2, markersize=10, label='Mean KL Divergence (binned)', color='steelblue')
ax.fill_between(bin_centers, binned_kl - binned_std, binned_kl + binned_std, alpha=0.2, color='steelblue', label='±1 Std Dev')

ax.set_xlabel('Normalised Prior Variance (σ² / $σ²_{uniform}$)', fontsize=12)
ax.set_ylabel('KL Divergence from Gaussian', fontsize=12)
ax.set_title('KL Divergence of X10 Belief vs Prior Confidence (Std Dev)', fontsize=14, fontweight='bold')

ax.set_xlim([0, 1.05])
ax.set_ylim(bottom=0)
ax.grid(True, alpha=0.3)
ax.legend(fontsize=11)

plt.tight_layout()
plt.savefig('kl_divergence_vs_variance.svg', format='svg', dpi=300, bbox_inches='tight')
plt.show()
